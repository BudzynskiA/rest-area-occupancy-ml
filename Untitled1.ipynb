# %%
import pandas as pd

final_df = pd.read_csv("rest_area_occupancy_merged.csv")

print("Basic info about the loaded DataFrame:")
print(final_df.info())
# Out:
# Basic info about the loaded DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10740 entries, 0 to 10739
# Data columns (total 33 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Restauracja /Bistro                              5712 non-null   object
#  1   Miejsca noclegowe                                5712 non-null   object
#  2   Occupancy                                        10740 non-null  object
#  3   Oddział                                          10608 non-null  object
#  4   Warsztat                                         5712 non-null   object
#  5   Parking Osobowe                                  10608 non-null  float64
#  6   Możliwość tankowania CNG                         5712 non-null   object
#  7   Dane identyfikacyjne                             10608 non-null  object
# ...

# %%
print("Descriptive stats (if numeric columns exist):")
print(final_df.describe(include='all'))
# Out:
# Descriptive stats (if numeric columns exist):
#        Restauracja /Bistro Miejsca noclegowe Occupancy   Oddział Warsztat  \
# count                 5712              5712     10740     10608     5712
# unique                   2                 2         3         4        2
# top                    tak               nie    medium  Katowice      nie
# freq                  3864              4536      5455      7728     4368
# mean                   NaN               NaN       NaN       NaN      NaN
# std                    NaN               NaN       NaN       NaN      NaN
# min                    NaN               NaN       NaN       NaN      NaN
# 25%                    NaN               NaN       NaN       NaN      NaN
# 50%                    NaN               NaN       NaN       NaN      NaN
# 75%                    NaN               NaN       NaN       NaN      NaN
# max                    NaN               NaN       NaN       NaN      NaN
#
# ...
